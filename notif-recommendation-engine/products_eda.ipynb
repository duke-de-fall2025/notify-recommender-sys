# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    "styles.csv",
    on_bad_lines="skip",
    encoding="utf-8"
)

# %%
# Rename columns
df = df.rename(columns={
    "id": "product_id",
    "productDisplayName": "title",
    "masterCategory": "master_category",
    "subCategory": "sub_category",
    "articleType": "article_type",
    "baseColour": "base_colour"
})

# %%
df["product_id"] = df["product_id"].astype(str)

# %%
# Clean missing values

df = df.dropna(subset=["product_id", "title"])

# %%
df
# Out:
#       product_id gender master_category sub_category           article_type  \
# 0          15970    Men         Apparel      Topwear                 Shirts
# 1          39386    Men         Apparel   Bottomwear                  Jeans
# 2          59263  Women     Accessories      Watches                Watches
# 3          21379    Men         Apparel   Bottomwear            Track Pants
# 4          53759    Men         Apparel      Topwear                Tshirts
# ...          ...    ...             ...          ...                    ...
# 44419      17036    Men        Footwear        Shoes           Casual Shoes
# 44420       6461    Men        Footwear   Flip Flops             Flip Flops
# 44421      18842    Men         Apparel      Topwear                Tshirts
# 44422      46694  Women   Personal Care    Fragrance  Perfume and Body Mist
# 44423      51623  Women     Accessories      Watches                Watches
#
#       base_colour  season    year   usage  \
# 0       Navy Blue    Fall  2011.0  Casual
# 1            Blue  Summer  2012.0  Casual
# 2          Silver  Winter  2016.0  Casual
# 3           Black    Fall  2011.0  Casual
# 4            Grey  Summer  2012.0  Casual
# ...           ...     ...     ...     ...
# 44419       White  Summer  2013.0  Casual
# 44420         Red  Summer  2011.0  Casual
# 44421        Blue    Fall  2011.0  Casual
# 44422        Blue  Spring  2017.0  Casual
# 44423        Pink  Winter  2016.0  Casual
#
#                                                  title
# 0                     Turtle Check Men Navy Blue Shirt
# 1                   Peter England Men Party Blue Jeans
# 2                             Titan Women Silver Watch
# 3        Manchester United Men Solid Black Track Pants
# 4                                Puma Men Grey T-shirt
# ...                                                ...
# 44419                        Gas Men Caddy Casual Shoe
# 44420               Lotto Men's Soccer Track Flip Flop
# 44421             Puma Men Graphic Stellar Blue Tshirt
# 44422                   Rasasi Women Blue Lady Perfume
# 44423  Fossil Women Pink Dial Chronograph Watch ES3050
#
# [44417 rows x 10 columns]

# %%
# Generate prices

def generate_price(row):
    cat = row["master_category"]

    if cat == "Footwear":
        return np.random.randint(1200, 3500)
    elif cat == "Apparel":
        return np.random.randint(800, 2500)
    elif cat == "Accessories":
        return np.random.randint(300, 2000)
    else:
        return np.random.randint(500, 2000)

df["price"] = df.apply(generate_price, axis=1)

# %%
# Check columns

df.columns.tolist()
# Out:
# ['product_id',
#  'gender',
#  'master_category',
#  'sub_category',
#  'article_type',
#  'base_colour',
#  'season',
#  'year',
#  'usage',
#  'title',
#  'price']

# %%
df.head()
# Out:
#   product_id gender master_category sub_category article_type base_colour  \
# 0      15970    Men         Apparel      Topwear       Shirts   Navy Blue
# 1      39386    Men         Apparel   Bottomwear        Jeans        Blue
# 2      59263  Women     Accessories      Watches      Watches      Silver
# 3      21379    Men         Apparel   Bottomwear  Track Pants       Black
# 4      53759    Men         Apparel      Topwear      Tshirts        Grey
#
#    season    year   usage                                          title  \
# 0    Fall  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  Summer  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  Winter  2016.0  Casual                       Titan Women Silver Watch
# 3    Fall  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  Summer  2012.0  Casual                          Puma Men Grey T-shirt
#
#    price
# 0   2211
# 1   1273
# 2    865
# 3   1702
# 4   1771

# %%
# Check for missing values

df["product_id"].isna().sum()
# Out:
# 0

# %%
# Check if product id is unique

df["product_id"].nunique(), len(df)
# Out:
# (44417, 44417)

# %%
# Check for  missing titles

df["title"].isna().sum()
# Out:
# 0

# %%
# Check for missing category

df["master_category"].value_counts(dropna=False)
# Out:
# master_category
# Apparel           21397
# Accessories       11272
# Footwear           9219
# Personal Care      2398
# Free Items          105
# Sporting Goods       25
# Home                  1
# Name: count, dtype: int64

# %%
# Check price distribution

df["price"].describe()
# Out:
# count    44417.000000
# mean      1641.471193
# std        672.735331
# min        300.000000
# 25%       1146.000000
# 50%       1601.000000
# 75%       2062.000000
# max       3499.000000
# Name: price, dtype: float64

# %%
df["product_id"].head(), df["product_id"].tail()
# Out:
# (0    15970
#  1    39386
#  2    59263
#  3    21379
#  4    53759
#  Name: product_id, dtype: object,
#  44419    17036
#  44420     6461
#  44421    18842
#  44422    46694
#  44423    51623
#  Name: product_id, dtype: object)

# %%
# Check image mapping

import os

image_ids = set([f.split('.')[0] for f in os.listdir("images")])
len(image_ids)
# Out:
# 44441

# %%
df.shape
# Out:
# (44417, 11)

# %%
# Filter rows that have matching url

df = df[df["product_id"].isin(image_ids)]

# %%
df
# Out:
#       product_id gender master_category sub_category           article_type  \
# 0          15970    Men         Apparel      Topwear                 Shirts
# 1          39386    Men         Apparel   Bottomwear                  Jeans
# 2          59263  Women     Accessories      Watches                Watches
# 3          21379    Men         Apparel   Bottomwear            Track Pants
# 4          53759    Men         Apparel      Topwear                Tshirts
# ...          ...    ...             ...          ...                    ...
# 44419      17036    Men        Footwear        Shoes           Casual Shoes
# 44420       6461    Men        Footwear   Flip Flops             Flip Flops
# 44421      18842    Men         Apparel      Topwear                Tshirts
# 44422      46694  Women   Personal Care    Fragrance  Perfume and Body Mist
# 44423      51623  Women     Accessories      Watches                Watches
#
#       base_colour  season    year   usage  \
# 0       Navy Blue    Fall  2011.0  Casual
# 1            Blue  Summer  2012.0  Casual
# 2          Silver  Winter  2016.0  Casual
# 3           Black    Fall  2011.0  Casual
# 4            Grey  Summer  2012.0  Casual
# ...           ...     ...     ...     ...
# 44419       White  Summer  2013.0  Casual
# 44420         Red  Summer  2011.0  Casual
# 44421        Blue    Fall  2011.0  Casual
# 44422        Blue  Spring  2017.0  Casual
# 44423        Pink  Winter  2016.0  Casual
#
#                                                  title  price
# 0                     Turtle Check Men Navy Blue Shirt   2211
# 1                   Peter England Men Party Blue Jeans   1273
# 2                             Titan Women Silver Watch    865
# 3        Manchester United Men Solid Black Track Pants   1702
# 4                                Puma Men Grey T-shirt   1771
# ...                                                ...    ...
# 44419                        Gas Men Caddy Casual Shoe   2026
# 44420               Lotto Men's Soccer Track Flip Flop   3025
# 44421             Puma Men Graphic Stellar Blue Tshirt   2274
# 44422                   Rasasi Women Blue Lady Perfume    585
# 44423  Fossil Women Pink Dial Chronograph Watch ES3050   1732
#
# [44412 rows x 11 columns]

# %%
# Export cleaned data 
df.to_csv("products_cleaned_no_img.csv", index=False)

# %%
# Add img urls to csv

products = pd.read_csv("products_cleaned_no_img.csv")

bucket = "notify-products"   # YOUR bucket name here
base_url = f"https://{bucket}.s3.amazonaws.com/images/fashion"

products["image_url"] = products["product_id"].apply(lambda x: f"{base_url}/{x}.jpg")

products.to_csv("products_clean.csv", index=False)

# %%
products
# Out:
#        product_id gender master_category sub_category           article_type  \
# 0           15970    Men         Apparel      Topwear                 Shirts
# 1           39386    Men         Apparel   Bottomwear                  Jeans
# 2           59263  Women     Accessories      Watches                Watches
# 3           21379    Men         Apparel   Bottomwear            Track Pants
# 4           53759    Men         Apparel      Topwear                Tshirts
# ...           ...    ...             ...          ...                    ...
# 44407       17036    Men        Footwear        Shoes           Casual Shoes
# 44408        6461    Men        Footwear   Flip Flops             Flip Flops
# 44409       18842    Men         Apparel      Topwear                Tshirts
# 44410       46694  Women   Personal Care    Fragrance  Perfume and Body Mist
# 44411       51623  Women     Accessories      Watches                Watches
#
#       base_colour  season    year   usage  \
# 0       Navy Blue    Fall  2011.0  Casual
# 1            Blue  Summer  2012.0  Casual
# 2          Silver  Winter  2016.0  Casual
# 3           Black    Fall  2011.0  Casual
# 4            Grey  Summer  2012.0  Casual
# ...           ...     ...     ...     ...
# 44407       White  Summer  2013.0  Casual
# 44408         Red  Summer  2011.0  Casual
# 44409        Blue    Fall  2011.0  Casual
# 44410        Blue  Spring  2017.0  Casual
# 44411        Pink  Winter  2016.0  Casual
#
#                                                  title  price  \
# 0                     Turtle Check Men Navy Blue Shirt   2211
# 1                   Peter England Men Party Blue Jeans   1273
# 2                             Titan Women Silver Watch    865
# 3        Manchester United Men Solid Black Track Pants   1702
# 4                                Puma Men Grey T-shirt   1771
# ...                                                ...    ...
# 44407                        Gas Men Caddy Casual Shoe   2026
# 44408               Lotto Men's Soccer Track Flip Flop   3025
# 44409             Puma Men Graphic Stellar Blue Tshirt   2274
# 44410                   Rasasi Women Blue Lady Perfume    585
# 44411  Fossil Women Pink Dial Chronograph Watch ES3050   1732
#
#                                                image_url
# 0      https://notify-products.s3.amazonaws.com/image...
# 1      https://notify-products.s3.amazonaws.com/image...
# 2      https://notify-products.s3.amazonaws.com/image...
# 3      https://notify-products.s3.amazonaws.com/image...
# 4      https://notify-products.s3.amazonaws.com/image...
# ...                                                  ...
# 44407  https://notify-products.s3.amazonaws.com/image...
# 44408  https://notify-products.s3.amazonaws.com/image...
# 44409  https://notify-products.s3.amazonaws.com/image...
# 44410  https://notify-products.s3.amazonaws.com/image...
# 44411  https://notify-products.s3.amazonaws.com/image...
#
# [44412 rows x 12 columns]
